# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\ramya\\Downloads\\yield.csv")
df
# Out:
#       Domain Code Domain  Area Code         Area  Element Code Element  \
# 0              QC  Crops          2  Afghanistan          5419   Yield
# 1              QC  Crops          2  Afghanistan          5419   Yield
# 2              QC  Crops          2  Afghanistan          5419   Yield
# 3              QC  Crops          2  Afghanistan          5419   Yield
# 4              QC  Crops          2  Afghanistan          5419   Yield
# ...           ...    ...        ...          ...           ...     ...
# 56712          QC  Crops        181     Zimbabwe          5419   Yield
# 56713          QC  Crops        181     Zimbabwe          5419   Yield
# 56714          QC  Crops        181     Zimbabwe          5419   Yield
# 56715          QC  Crops        181     Zimbabwe          5419   Yield
# 56716          QC  Crops        181     Zimbabwe          5419   Yield
#
#        Item Code   Item  Year Code  Year   Unit  Value
# 0             56  Maize       1961  1961  hg/ha  14000
# ...

# %%
y=df['Value']
y
# Out:
# 0        14000
# 1        14000
# 2        14260
# 3        14257
# 4        14400
#          ...
# 56712    24420
# 56713    22888
# 56714    21357
# 56715    19826
# 56716    18294
# Name: Value, Length: 56717, dtype: int64

# %%
x=df.drop('Value',axis=1)
x
# Out:
#       Domain Code Domain  Area Code         Area  Element Code Element  \
# 0              QC  Crops          2  Afghanistan          5419   Yield
# 1              QC  Crops          2  Afghanistan          5419   Yield
# 2              QC  Crops          2  Afghanistan          5419   Yield
# 3              QC  Crops          2  Afghanistan          5419   Yield
# 4              QC  Crops          2  Afghanistan          5419   Yield
# ...           ...    ...        ...          ...           ...     ...
# 56712          QC  Crops        181     Zimbabwe          5419   Yield
# 56713          QC  Crops        181     Zimbabwe          5419   Yield
# 56714          QC  Crops        181     Zimbabwe          5419   Yield
# 56715          QC  Crops        181     Zimbabwe          5419   Yield
# 56716          QC  Crops        181     Zimbabwe          5419   Yield
#
#        Item Code   Item  Year Code  Year   Unit
# 0             56  Maize       1961  1961  hg/ha
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       Domain Code Domain  Area Code         Area  Element Code Element  \
# 0              QC  Crops          2  Afghanistan          5419   Yield
# 1              QC  Crops          2  Afghanistan          5419   Yield
# 2              QC  Crops          2  Afghanistan          5419   Yield
# 3              QC  Crops          2  Afghanistan          5419   Yield
# 4              QC  Crops          2  Afghanistan          5419   Yield
# ...           ...    ...        ...          ...           ...     ...
# 56712          QC  Crops        181     Zimbabwe          5419   Yield
# 56713          QC  Crops        181     Zimbabwe          5419   Yield
# 56714          QC  Crops        181     Zimbabwe          5419   Yield
# 56715          QC  Crops        181     Zimbabwe          5419   Yield
# 56716          QC  Crops        181     Zimbabwe          5419   Yield
#
#        Item Code   Item  Year Code  Year   Unit  Value
# 0             56  Maize       1961  1961  hg/ha  14000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb= LabelEncoder()
df['Domain Code']=lb.fit_transform(df['Domain Code'])
df['Domain']=lb.fit_transform(df['Domain'])
df['Area']=lb.fit_transform(df['Area'])
df['Element']=lb.fit_transform(df['Element'])
df['Item']=lb.fit_transform(df['Item'])
df['Unit']=lb.fit_transform(df['Unit'])

# %%
df
# Out:
#        Domain Code  Domain  Area Code  Area  Element Code  Element  Item Code  \
# 0                0       0          2     0          5419        0         56
# 1                0       0          2     0          5419        0         56
# 2                0       0          2     0          5419        0         56
# 3                0       0          2     0          5419        0         56
# 4                0       0          2     0          5419        0         56
# ...            ...     ...        ...   ...           ...      ...        ...
# 56712            0       0        181   211          5419        0         15
# 56713            0       0        181   211          5419        0         15
# 56714            0       0        181   211          5419        0         15
# 56715            0       0        181   211          5419        0         15
# 56716            0       0        181   211          5419        0         15
#
# ...

# %%
x=df.drop('Value',axis=1)
x
# Out:
#        Domain Code  Domain  Area Code  Area  Element Code  Element  Item Code  \
# 0                0       0          2     0          5419        0         56
# 1                0       0          2     0          5419        0         56
# 2                0       0          2     0          5419        0         56
# 3                0       0          2     0          5419        0         56
# 4                0       0          2     0          5419        0         56
# ...            ...     ...        ...   ...           ...      ...        ...
# 56712            0       0        181   211          5419        0         15
# 56713            0       0        181   211          5419        0         15
# 56714            0       0        181   211          5419        0         15
# 56715            0       0        181   211          5419        0         15
# 56716            0       0        181   211          5419        0         15
#
# ...

# %%
y=df['Value']
y
# Out:
# 0        14000
# 1        14000
# 2        14260
# 3        14257
# 4        14400
#          ...
# 56712    24420
# 56713    22888
# 56714    21357
# 56715    19826
# 56716    18294
# Name: Value, Length: 56717, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x_train
# Out:
#        Domain Code  Domain  Area Code  Area  Element Code  Element  Item Code  \
# 14676            0       0        116    53          5419        0         83
# 40537            0       0        171   148          5419        0        116
# 49425            0       0        208   185          5419        0        116
# 29294            0       0        122   108          5419        0        116
# 36268            0       0        157   135          5419        0         56
# ...            ...     ...        ...   ...           ...      ...        ...
# 50057            0       0        176   188          5419        0        125
# 32511            0       0        136   120          5419        0        137
# 5192             0       0         19    22          5419        0         83
# 12172            0       0         45    43          5419        0         27
# 33003            0       0        138   122          5419        0         27
#
# ...

# %%
x_test
# Out:
#        Domain Code  Domain  Area Code  Area  Element Code  Element  Item Code  \
# 25186            0       0        101    92          5419        0        236
# 7466             0       0         29    29          5419        0        137
# 3304             0       0         16    13          5419        0         15
# 41315            0       0        174   150          5419        0        137
# 23397            0       0         93    87          5419        0        116
# ...            ...     ...        ...   ...           ...      ...        ...
# 10082            0       0        351    38          5419        0        125
# 47610            0       0         38   178          5419        0        236
# 3568             0       0         57    15          5419        0         56
# 20209            0       0         73    76          5419        0        116
# 1749             0       0          9     6          5419        0         83
#
# ...

# %%
y_train
# Out:
# 14676     11818
# 40537    122823
# 49425    100289
# 29294    160000
# 36268      8482
#           ...
# 50057     34722
# 32511     62760
# 5192      40356
# 12172     11111
# 33003     57122
# Name: Value, Length: 39701, dtype: int64

# %%
y_test
# Out:
# 25186      9784
# 7466      57000
# 3304      16767
# 41315     81455
# 23397    121373
#           ...
# 10082    123054
# 47610     11092
# 3568      39390
# 20209    117820
# 1749      46534
# Name: Value, Length: 17016, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor(max_depth=2,random_state=100)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %%
#making prediction

# %%
y_rf_train_pred=rf.predict(x_train)
y_rf_test_pred=rf.predict(x_test)

# %%
#evaluating

# %%
from sklearn.metrics import mean_squared_error,r2_score,accuracy_score

# %%
rf_train_mse=mean_squared_error(y_train,y_rf_train_pred)
rf_train_r2=r2_score(y_train,y_rf_train_pred)

# %%
rf_test_mse=mean_squared_error(y_test,y_rf_test_pred)
rf_test_r2=r2_score(y_test,y_rf_test_pred)

# %%
rf_results=pd.DataFrame(['RandomForest',rf_train_mse,rf_train_r2,rf_test_mse,rf_test_r2]).transpose()
rf_results.columns=['Method','Training MSE','Training R2','Test MSE','Test R2']
rf_results
# Out:
#          Method       Training MSE Training R2           Test MSE   Test R2
# 0  RandomForest  2869648158.111673    0.379172  2748910481.952506  0.396292

# %%
#predicting

# %%
y_pred=rf.predict(x_test)

# %%
y_pred
# Out:
# array([ 74944.96104985,  74944.96104985,  26538.78290873, ...,
#         31989.48561278, 149553.1474216 ,  31989.48561278])

# %%
y_pred=rf.predict([[0,0,2,0,5419,0,56,1,1961,1961,0]])
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([20462.39595925])
